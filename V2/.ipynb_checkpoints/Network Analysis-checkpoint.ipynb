# %%
import pandas as pd
import numpy as np
import json
import pip
import re
from urllib.request import urlopen
import requests
from wikidata.client import Client
from scipy import stats
import powerlaw
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import pickle
from fa2 import ForceAtlas2
import operator
from backbone import *
import community
from collections import Counter

# %%
df = pd.read_pickle("connections.pkl")
df
# Out:
#                                        id                      name  \
# 0    eaf0104e-b8ae-4336-a353-ca5228fe2752        A. Donald McEachin
# 1    c5441370-42c5-4d83-b73e-6130cc4910cc       A. Drew Ferguson IV
# 2    05165473-b19d-484d-8de3-e6ed420cc299           Abby Finkenauer
# 3    6133038f-b893-45d2-aa09-a7feb433edf7  Abigail Davis Spanberger
# 4    e0b61cab-a183-4a44-bb0a-81f25fda8de3            Adam B. Schiff
# ..                                    ...                       ...
# 535  be1429b6-d20f-4984-9c55-86fc973242df                 Tim Scott
# 536  7cd602d6-2486-4971-abda-ae5516b7b6fc                Tina Smith
# 537  99537cde-00d9-41d3-af9c-247f13215944                Todd Young
# 538  d7bfdfde-86cd-4da5-99d5-5c560561d7cc                Tom Cotton
# 539  d93db7bd-499d-4309-a963-0ebf27d05be4                 Tom Udall
#
#                sort_name  email          twitter          facebook  \
# 0           McEachin, A.    NaN      RepMcEachin       RepMcEachin
# 1           Ferguson, A.    NaN  RepDrewFerguson   RepDrewFerguson
# 2       Finkenauer, Abby    NaN              NaN               NaN
# 3    Spanberger, Abigail    NaN              NaN               NaN
# 4           Schiff, Adam    NaN    RepAdamSchiff     RepAdamSchiff
# ..                   ...    ...              ...               ...
# 535           Scott, Tim    NaN  SenatorTimScott   SenatorTimScott
# 536          Smith, Tina    NaN     SenTinaSmith    USSenTinaSmith
# 537          Young, Todd    NaN     SenToddYoung  SenatorToddYoung
# 538          Cotton, Tom    NaN     SenTomCotton  SenatorTomCotton
# 539           Udall, Tom    NaN  SenatorTomUdall   senatortomudall
#
#           group    group_id                           area_id  \
# 0      Democrat    democrat                              VA-4
# 1    Republican  republican                              GA-3
# 2      Democrat    democrat                              IA-1
# 3      Democrat    democrat                              VA-7
# 4      Democrat    democrat                             CA-28
# ..          ...         ...                               ...
# 535  Republican  republican  ocd-division/country:us/state:sc
# 536    Democrat    democrat  ocd-division/country:us/state:mn
# 537  Republican  republican  ocd-division/country:us/state:in
# 538  Republican  republican  ocd-division/country:us/state:ar
# 539    Democrat    democrat  ocd-division/country:us/state:nm
#
#                                          area  ... term  start_date end_date  \
# 0       Virginia's 4th congressional district  ...  116         NaN      NaN
# 1        Georgia's 3rd congressional district  ...  116         NaN      NaN
# 2           Iowa's 1st congressional district  ...  116         NaN      NaN
# 3       Virginia's 7th congressional district  ...  116         NaN      NaN
# 4    California's 28th congressional district  ...  116         NaN      NaN
# ..                                        ...  ...  ...         ...      ...
# 535                            South Carolina  ...  116         NaN      NaN
# 536                                 Minnesota  ...  116         NaN      NaN
# 537                                   Indiana  ...  116         NaN      NaN
# 538                                  Arkansas  ...  116         NaN      NaN
# 539                                New Mexico  ...  116         NaN      NaN
#
#                                                  image  gender   wikidata  \
# 0    https://theunitedstates.io/images/congress/ori...    male   Q4647699
# 1    https://theunitedstates.io/images/congress/ori...    male  Q26157659
# 2    https://theunitedstates.io/images/congress/ori...  female  Q24435337
# 3    https://theunitedstates.io/images/congress/ori...  female  Q55603085
# 4    https://theunitedstates.io/images/congress/ori...    male    Q350843
# ..                                                 ...     ...        ...
# 535  https://theunitedstates.io/images/congress/ori...    male    Q561315
# 536  https://theunitedstates.io/images/congress/ori...  female  Q18631509
# 537  https://theunitedstates.io/images/congress/ori...    male     Q25483
# 538  https://theunitedstates.io/images/congress/ori...    male   Q3090307
# 539  https://theunitedstates.io/images/congress/ori...    male    Q957690
#
#     wikidata_group wikidata_area connections  \
# 0           Q29552      Q7934058           0
# 1           Q29468      Q5547263           2
# 2           Q29552     Q13858962           2
# 3           Q29552      Q7934064           6
# 4           Q29552      Q5020000           7
# ..             ...           ...         ...
# 535         Q29468         Q1456           9
# 536         Q29552         Q1527          12
# 537         Q29468         Q1415           8
# 538         Q29468         Q1612          19
# 539         Q29552         Q1522           4
#
#                                                  links
# 0    [Virginia, Randy Forbes, Virginia's 9th Senate...
# 1    [Party leaders of the United States House of R...
# 2    [Iowa, Ashley Hinson, Rod Blum, Pat Murphy (Io...
# 3    [Virginia, Dave Brat, Red Bank, New Jersey, De...
# 4    [United States House Permanent Select Committe...
# ..                                                 ...
# 535  [United States Senate Special Committee on Agi...
# 536  [Minnesota, Amy Klobuchar, Al Franken, List of...
# 537  [Indiana, Mike Braun, Dan Coats, National Repu...
# 538  [Arkansas, John Boozman, Mark Pryor, Arkansas,...
# 539  [List of ambassadors of the United States to N...
#
# [540 rows x 21 columns]

# %% [markdown]
# # Graph Creation

# %%
def graphCreator(DG, df):
    # Creating directed network
    for politician in df.name:
        party = df.loc[df.name == politician, 'group'].values[0]
        chamber = df.loc[df.name == politician, 'chamber'].values[0]
        DG.add_nodes_from([(politician, {'Party' : party, 'Chamber' : chamber})])

        links = df.loc[df.name == politician, 'links'].values[0]
        linkCounts = Counter(links)
        
        
        try:
            for name in df.name:
                if name in linkCounts.keys():
                    party = df.loc[df.name == name, 'group'].values[0]
                    DG.add_nodes_from([(name, {'Party' : party})])
                    DG.add_edge(politician, name, weight = linkCounts[name])
        except TypeError:
            pass

# %%
DG = nx.DiGraph()
graphCreator(DG, df)

# %%
print(f'Nodes: {DG.number_of_nodes()}')
print(f'Edges: {DG.number_of_edges()}\n')

#Extract largest component
nodes = max(nx.weakly_connected_components(DG), key=len)
DG = DG.subgraph(nodes).copy()

print(f'Nodes: {DG.number_of_nodes()}')
print(f'Edges: {DG.number_of_edges()}\n')
# Out:
# Nodes: 540
# Edges: 2365
#
# Nodes: 523
# Edges: 2363

# %% [markdown]
# # Graph Analysis

# %%
count = 0
for a,b in DG.edges():
    # print(DG.nodes[a]['Party'])
    if DG.nodes[a]['Party'] != DG.nodes[b]['Party']:
        count = count+1
print(f'Number of links between Democrats and Republicans: {count}')
# Out:
# Number of links between Democrats and Republicans: 788

# %%
in_degrees = sorted((d for n, d in DG.in_degree()), reverse=False)
out_degrees = sorted((d for n, d in DG.out_degree()), reverse=True)

print(f'in-degree stats: \nMean: {np.mean(in_degrees)} \nMedian: {np.median(in_degrees)}   \nMode: {stats.mode(in_degrees)} \nMinimum:  {np.min(in_degrees)} \nMaximum: {np.max(in_degrees)} \n')

print(f'out-degree stats: \nMean: {np.mean(out_degrees)} \nMedian: {np.median(out_degrees)}   \nMode: {stats.mode(out_degrees)} \nMinimum:  {np.min(out_degrees)} \nMaximum: {np.max(out_degrees)}')
# Out:
# in-degree stats:
# Mean: 4.5181644359464626
# Median: 2.0
# Mode: ModeResult(mode=array([0]), count=array([218]))
# Minimum:  0
# Maximum: 153
#
# out-degree stats:
# Mean: 4.5181644359464626
# Median: 3.0
# Mode: ModeResult(mode=array([2]), count=array([107]))
# Minimum:  0
# Maximum: 29

# %%
# Binning the degree distribution
bins_in_degrees = np.arange(np.min(in_degrees),np.max(in_degrees),1)
freq_in_degrees, hist_in_degrees = np.histogram(in_degrees, bins = bins_in_degrees);
bins_out_degrees = np.arange(np.min(out_degrees),np.max(out_degrees),1)
freq_out_degrees, hist_out_degrees = np.histogram(out_degrees, bins = bins_out_degrees);

p_k_in = [i/np.sum(freq_in_degrees) for i in freq_in_degrees]
p_k_out = [i/np.sum(freq_out_degrees) for i in freq_out_degrees]


# Plotting
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))
fig.tight_layout()
ax1.set_title('In degree distribution', fontsize = 20)
ax1.set_xlabel('degree k', fontsize = 12)
ax1.set_ylabel("$p_{k}$", fontsize = 14)
#ax1.set_xlim(0,100)
ax1.set_xscale("log");
ax1.set_yscale("log");
#ax1.scatter(*np.unique(in_degrees, return_counts=True), color = 'purple');
#ax1.scatter(hist_in_degrees[:-1], freq_in_degrees, color = 'purple');
ax1.scatter(hist_in_degrees[:-1], p_k_in, color = 'purple');

ax2.set_title('Out degree distribution', fontsize = 20)
ax2.set_xlabel('degree k', fontsize = 12)
ax2.set_ylabel('$p_{k}$', fontsize = 14)
#ax2.set_xlim(0,100)
#ax2.set_ylim(0,0.08)
#ax2.bar(*np.unique(out_degrees, return_counts=True), color = 'purple');
#ax2.bar(hist_out_degrees[:-1], freq_out_degrees, color = 'purple');
ax2.bar(hist_out_degrees[:-1], p_k_out, color = 'purple');

plt.subplots_adjust(wspace = 0.2)



fit = powerlaw.Fit(in_degrees)
gamma = fit.alpha
print(f'The slope of the in degree distribution when fitted with a power law: {gamma}')
powerlaw_fit = [d**(-gamma) for d in hist_in_degrees[1:]]
ax1.plot(hist_in_degrees[1:], powerlaw_fit, c = 'grey', linestyle='dashed');
# Out:
# The slope of the in degree distribution when fitted with a power law: 3.134479977393144
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# C:\Users\magma\anaconda3\lib\site-packages\powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /

# %%
top_in_degrees = sorted(DG.in_degree(), key = operator.itemgetter(1,0), reverse = True)
top_out_degrees = sorted(DG.out_degree(), key = operator.itemgetter(1,0), reverse = True)

print(f'Top 10 in_degree:')
for name, count in top_in_degrees[:10]:
    print(f"{name :<25}: {count}")
    
print(f'\nTop 10 out_degree:')
for name, count in top_out_degrees[:10]:
    print(f"{name:<25}: {count}")
# Out:
# Top 10 in_degree:
# Nancy Pelosi             : 153
# Mitch McConnell          : 52
# Ted Cruz                 : 48
# Mitt Romney              : 46
# Elizabeth Warren         : 43
# Rand Paul                : 38
# Marco Rubio              : 37
# Lindsey Graham           : 34
# John Cornyn              : 31
# Alexandria Ocasio-Cortez : 30
#
# Top 10 out_degree:
# Chip Roy                 : 29
# Tom Cotton               : 19
# Kevin McCarthy           : 19
# Paul A. Gosar            : 18
# Mike Lee                 : 18
# Joe Manchin, III         : 18
# Charles E. Schumer       : 18
# Patrick J. Leahy         : 17
# Doug Jones               : 17
# Liz Cheney               : 16

# %% [markdown]
# # Drawing the graph

# %%
# Convert to undirected graph for plotting
UGCC = DG.to_undirected()

# %%
print(f'Nodes: {UGCC.number_of_nodes()}')
print(f'Edges: {UGCC.number_of_edges()}\n')
# Out:
# Nodes: 523
# Edges: 1963

# %%
# Assigning node colors and sizes based on party and degree
node_color = []
for node, attribute in UGCC.nodes(data=True):
    if attribute['Party'] == 'Republican':
        node_color.append('red')
    else:
        node_color.append('Blue')

edge_color = []
for n1, n2 in UGCC.edges():
    uni1 = UGCC.nodes[n1]['Party']
    uni2 = UGCC.nodes[n2]['Party']
    if uni1 == 'Republican' and uni2 == 'Republican':
        edge_color.append('orange')
    elif uni1 != uni2:
        edge_color.append('green')
    else:
        edge_color.append('yellow')
        
d = dict(UGCC.degree).values()
scale = 10
node_size = [degree*scale for degree in d]

# %%
forceatlas2 = ForceAtlas2(
                        # Behavior alternatives
                        outboundAttractionDistribution=True,  # Dissuade hubs
                        linLogMode=False,  # NOT IMPLEMENTED
                        adjustSizes=False,  # Prevent overlap (NOT IMPLEMENTED)
                        edgeWeightInfluence=1.0,

                        # Performance
                        jitterTolerance=1.0,  # Tolerance
                        barnesHutOptimize=True,
                        barnesHutTheta=1.0,
                        multiThreaded=False,  # NOT IMPLEMENTED

                        # Tuning
                        scalingRatio=2,
                        strongGravityMode=False,
                        gravity=1.5,

                        # Log
                        verbose=True)

positions = forceatlas2.forceatlas2_networkx_layout(UGCC, pos=None, iterations=500);
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 500/500 [00:04<00:00, 109.35it/s]
# BarnesHut Approximation  took  0.47  seconds
# Repulsion forces  took  3.92  seconds
# Gravitational forces  took  0.01  seconds
# Attraction forces  took  0.01  seconds
# AdjustSpeedAndApplyForces step  took  0.08  seconds

# %%
plt.figure(1,figsize=(20,12)) 
plt.title('Graph of Republican and Democratic candidates based on connections')
nx.draw_networkx_nodes(UGCC, pos = positions, node_size=node_size, node_color=node_color, alpha=0.9);
nx.draw_networkx_edges(UGCC, pos = positions, edge_color=edge_color, alpha=0.2);
plt.show()

# %% [markdown]
# # Finding comunities

# %%
# Best partition found with louvain algorithm
partition = community.best_partition(UGCC, random_state = 1, randomize = False)

# Defining values for the color spectrum
maxval = np.max(list(partition.values())) 
cmap=plt.cm.Spectral
node_color = [cmap(v/maxval) for v in partition.values()]

# Plotting
plt.figure(1,figsize=(20,12)) 
nx.draw_networkx_nodes(UGCC, pos = positions, node_color=node_color, alpha=0.9, node_size = node_size);
nx.draw_networkx_edges(UGCC, pos = positions, alpha=0.04);

# For legend creation only
for v in set(partition.values()):
    plt.scatter([],[], c=[cmap(v/maxval)], label='Community {}'.format(v))

plt.title('Politician Network nodes colored by community', fontsize = 20)
plt.legend(loc='upper left', prop={'size': 14})
plt.show()

# %% [markdown]
# # Filtering network

# %%
#filteredNetwork = disparity_filter(UGCC)

# %%
#alpha = 0.9
#backboneNetwork = nx.Graph([(u, v, d) for u, v, d in filteredNetwork.edges(data=True) if d['alpha'] < alpha])

# %%
# Best partition found with louvain algorithm
#partition = community.best_partition(backboneNetwork, random_state = 1, randomize = False)

# Defining values for the color spectrum
#maxval = np.max(list(partition.values())) 
#cmap=plt.cm.Spectral
#node_color = [cmap(v/maxval) for v in partition.values()]

# Plotting
#plt.figure(1,figsize=(20,12)) 
#nx.draw_networkx_nodes(backboneNetwork, pos = positions, node_color=node_color, alpha=0.9, node_size = 20);#, node_size = node_size);
#nx.draw_networkx_edges(backboneNetwork, pos = positions, alpha=0.1);

# For legend creation only
#for v in set(partition.values()):
#    plt.scatter([],[], c=[cmap(v/maxval)], label='Community {}'.format(v))

#plt.title('Politician Network nodes colored by community', fontsize = 20)
#plt.legend(loc='upper left', prop={'size': 14})
#plt.show()

# %% [markdown]
# # Centrality measures
#
# **Degree**

# %%
sorted(DG.in_degree(), key = operator.itemgetter(1,0), reverse = True)[:10]
# Out:
# [('Nancy Pelosi', 153),
#  ('Mitch McConnell', 52),
#  ('Ted Cruz', 48),
#  ('Mitt Romney', 46),
#  ('Elizabeth Warren', 43),
#  ('Rand Paul', 38),
#  ('Marco Rubio', 37),
#  ('Lindsey Graham', 34),
#  ('John Cornyn', 31),
#  ('Alexandria Ocasio-Cortez', 30)]

# %%
sorted(DG.out_degree(), key = operator.itemgetter(1,0), reverse = True)[:10]
# Out:
# [('Chip Roy', 29),
#  ('Tom Cotton', 19),
#  ('Kevin McCarthy', 19),
#  ('Paul A. Gosar', 18),
#  ('Mike Lee', 18),
#  ('Joe Manchin, III', 18),
#  ('Charles E. Schumer', 18),
#  ('Patrick J. Leahy', 17),
#  ('Doug Jones', 17),
#  ('Liz Cheney', 16)]

# %% [markdown]
# **Betweenness Centrality**

# %%
sorted(nx.betweenness_centrality(DG).items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('Nancy Pelosi', 0.11977447287174023),
#  ('Mitt Romney', 0.05226693498612595),
#  ('Tom Cotton', 0.03208477198330774),
#  ('Ted Cruz', 0.03166881287461206),
#  ('Kyrsten Sinema', 0.026798068996890766),
#  ('Ilhan Omar', 0.02651214383210003),
#  ('Liz Cheney', 0.025921898207576004),
#  ('Alexandria Ocasio-Cortez', 0.023871225333730876),
#  ('Thomas Massie', 0.02192739097281948),
#  ('Rand Paul', 0.020712478373683174)]

# %% [markdown]
# **Eigenvector Centrality**

# %%
sorted(nx.eigenvector_centrality(DG).items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('Mitch McConnell', 0.3631303789157147),
#  ('Nancy Pelosi', 0.2565036722848349),
#  ('John Cornyn', 0.25598884925770726),
#  ('Rand Paul', 0.25585197805371596),
#  ('Ted Cruz', 0.2542660706073187),
#  ('Mitt Romney', 0.24643511059881515),
#  ('Chuck Grassley', 0.1887104385921964),
#  ('Lindsey Graham', 0.18734530811734942),
#  ('Marco Rubio', 0.17434402641615032),
#  ('Dianne Feinstein', 0.17370872263456708)]

# %% [markdown]
# # Assortativity

# %%
print(nx.attribute_assortativity_coefficient(DG, 'Party'))
print(nx.attribute_assortativity_coefficient(DG, 'Chamber'))
print(nx.degree_assortativity_coefficient(DG))
# Out:
# 0.3397775010566147
# 0.6821232799678323
# -0.00915651334314478

# %% [markdown]
# # Modularity

# %% [markdown]
# **By Party**

# %%
democrats = [node[0] for node in DG.nodes(data=True) if node[1]['Party'] == 'Democrat']
republicans = [node[0] for node in DG.nodes(data=True) if node[1]['Party'] == 'Republican']
independents = [node[0] for node in DG.nodes(data=True) if node[1]['Party'] == 'Independent']
print(f'{nx.algorithms.community.modularity(DG, [democrats,republicans,independents])}')
# Out:
# 0.18753473934637674

# %% [markdown]
# **By Chamber**

# %%
house = [node[0] for node in DG.nodes(data=True) if node[1]['Chamber'] == 'House of Representatives']
senate = [node[0] for node in DG.nodes(data=True) if node[1]['Chamber'] == 'Senate']
print(f'{nx.algorithms.community.modularity(DG, [house,senate])}')
# Out:
# 0.33483672842848816

# %% [markdown]
# **By Algorithm**

# %%
coms = []
for i in range(0, len(set(partition.values()))):
    coms.append([])
    
for politician, com in partition.items():
    coms[com].append(politician)

print(f'{nx.algorithms.community.modularity(DG, coms)}')
# Out:
# 0.4294019407391628
