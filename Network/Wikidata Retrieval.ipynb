# %% [markdown]
# # Declarations

# %%
def import_or_install(package):
#     source : 
#     stackoverflow.com/questions/4527554/check-if-module-exists-if-not-install-it
    """
    Input : string package
    Output : install package if it does not exist
    """
    try:
        __import__(package)
    except ImportError:
        pip.main(['install',package])

# %%
import pandas as pd
import numpy as np
import json
import pip
import re
from urllib.request import urlopen
import_or_install('wikidata')
import requests
from wikidata.client import Client
from scipy import stats
import powerlaw
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import pickle
from fa2 import ForceAtlas2
import operator

# %% [markdown]
# ## Functions declarations

# %%
def load_all_to_df(*datasets):
    """
    Input : strings of CSVs titles
    Output: pandas dataframe containg all records in all CSVs
    """
    df_list = [pd.read_csv(dataset) for dataset in datasets]
    return pd.concat(df_list, ignore_index=True)

# %%
def get_wikipedia_url(wikidata):
    """
    Input : string wikidata ID
    Output: wikipedia page url
    """
    client = Client()
    entity = client.get(wikidata, load=True)
    return entity.data['sitelinks']['enwiki']['url']

# %%
def get_json_wikipedia(url):
    baseurl = 'https://en.wikipedia.org/w/api.php?'
    action = 'action=query'
    content = '&prop=revisions&rvprop=content'
    dataformat = '&format=json'
    title = '&titles=' + get_wikipedia_title(url)
    query = "%s%s%s%s%s" % (baseurl,action,content,dataformat,title)
    
    wikiresponse = urlopen(query)
    wikisource = wikiresponse.read()
    wikitext = wikisource.decode('utf-8')
    jsontext = json.loads(wikitext)['query']
    return json.dumps(jsontext)

# %%
def find_wikilinks(df = None):
    """
    Input : pandas dataframe
    Output : pandas dataframe with a new column containing the number of links
    """
    linksList = []
    for wikiId in df.wikidata:
        url = get_wikipedia_url(wikiId)
        links = get_links_from_url(url)
        linksList.append(links)

    df['links'] = linksList
    return df

# %%
def get_links_from_url(url):
    pattern = r'\[\[(.*?)(?:\|.*?)?\]\]'
    wikitext = get_json_wikipedia(url)
    return re.findall(pattern, wikitext)

# %% [markdown]
# # Load data for all members: senate and congress

# %%
df_members = load_all_to_df('..//term-116_congress.csv','..//term-116_senate.csv')
df_connections = find_wikilinks(df_members)

# %%
df_connections
# Out:
#                                        id                      name  \
# 0    eaf0104e-b8ae-4336-a353-ca5228fe2752        A. Donald McEachin
# 1    c5441370-42c5-4d83-b73e-6130cc4910cc       A. Drew Ferguson IV
# 2    05165473-b19d-484d-8de3-e6ed420cc299           Abby Finkenauer
# 3    6133038f-b893-45d2-aa09-a7feb433edf7  Abigail Davis Spanberger
# 4    e0b61cab-a183-4a44-bb0a-81f25fda8de3            Adam B. Schiff
# ..                                    ...                       ...
# 535  be1429b6-d20f-4984-9c55-86fc973242df                 Tim Scott
# 536  7cd602d6-2486-4971-abda-ae5516b7b6fc                Tina Smith
# 537  99537cde-00d9-41d3-af9c-247f13215944                Todd Young
# 538  d7bfdfde-86cd-4da5-99d5-5c560561d7cc                Tom Cotton
# 539  d93db7bd-499d-4309-a963-0ebf27d05be4                 Tom Udall
#
#                sort_name  email          twitter          facebook  \
# 0           McEachin, A.    NaN      RepMcEachin       RepMcEachin
# 1           Ferguson, A.    NaN  RepDrewFerguson   RepDrewFerguson
# 2       Finkenauer, Abby    NaN              NaN               NaN
# 3    Spanberger, Abigail    NaN              NaN               NaN
# 4           Schiff, Adam    NaN    RepAdamSchiff     RepAdamSchiff
# ..                   ...    ...              ...               ...
# 535           Scott, Tim    NaN  SenatorTimScott   SenatorTimScott
# 536          Smith, Tina    NaN     SenTinaSmith    USSenTinaSmith
# 537          Young, Todd    NaN     SenToddYoung  SenatorToddYoung
# 538          Cotton, Tom    NaN     SenTomCotton  SenatorTomCotton
# 539           Udall, Tom    NaN  SenatorTomUdall   senatortomudall
#
#           group    group_id                           area_id  \
# 0      Democrat    democrat                              VA-4
# 1    Republican  republican                              GA-3
# 2      Democrat    democrat                              IA-1
# 3      Democrat    democrat                              VA-7
# 4      Democrat    democrat                             CA-28
# ..          ...         ...                               ...
# 535  Republican  republican  ocd-division/country:us/state:sc
# 536    Democrat    democrat  ocd-division/country:us/state:mn
# 537  Republican  republican  ocd-division/country:us/state:in
# 538  Republican  republican  ocd-division/country:us/state:ar
# 539    Democrat    democrat  ocd-division/country:us/state:nm
#
#                                          area                   chamber  term  \
# 0       Virginia's 4th congressional district  House of Representatives   116
# 1        Georgia's 3rd congressional district  House of Representatives   116
# 2           Iowa's 1st congressional district  House of Representatives   116
# 3       Virginia's 7th congressional district  House of Representatives   116
# 4    California's 28th congressional district  House of Representatives   116
# ..                                        ...                       ...   ...
# 535                            South Carolina                    Senate   116
# 536                                 Minnesota                    Senate   116
# 537                                   Indiana                    Senate   116
# 538                                  Arkansas                    Senate   116
# 539                                New Mexico                    Senate   116
#
#     start_date end_date                                              image  \
# 0          NaN      NaN  https://theunitedstates.io/images/congress/ori...
# 1          NaN      NaN  https://theunitedstates.io/images/congress/ori...
# 2          NaN      NaN  https://theunitedstates.io/images/congress/ori...
# 3          NaN      NaN  https://theunitedstates.io/images/congress/ori...
# 4          NaN      NaN  https://theunitedstates.io/images/congress/ori...
# ..         ...      ...                                                ...
# 535        NaN      NaN  https://theunitedstates.io/images/congress/ori...
# 536        NaN      NaN  https://theunitedstates.io/images/congress/ori...
# 537        NaN      NaN  https://theunitedstates.io/images/congress/ori...
# 538        NaN      NaN  https://theunitedstates.io/images/congress/ori...
# 539        NaN      NaN  https://theunitedstates.io/images/congress/ori...
#
#      gender   wikidata wikidata_group wikidata_area  \
# 0      male   Q4647699         Q29552      Q7934058
# 1      male  Q26157659         Q29468      Q5547263
# 2    female  Q24435337         Q29552     Q13858962
# 3    female  Q55603085         Q29552      Q7934064
# 4      male    Q350843         Q29552      Q5020000
# ..      ...        ...            ...           ...
# 535    male    Q561315         Q29468         Q1456
# 536  female  Q18631509         Q29552         Q1527
# 537    male     Q25483         Q29468         Q1415
# 538    male   Q3090307         Q29468         Q1612
# 539    male    Q957690         Q29552         Q1522
#
#                                                  links
# 0    [Virginia, Randy Forbes, Virginia's 9th Senate...
# 1    [Party leaders of the United States House of R...
# 2    [Iowa, Ashley Hinson, Rod Blum, Pat Murphy (Io...
# 3    [Virginia, Dave Brat, Red Bank, New Jersey, De...
# 4    [United States House Permanent Select Committe...
# ..                                                 ...
# 535  [United States Senate Special Committee on Agi...
# 536  [Minnesota, Amy Klobuchar, Al Franken, List of...
# 537  [Indiana, Mike Braun, Dan Coats, National Repu...
# 538  [Arkansas, John Boozman, Mark Pryor, Arkansas,...
# 539  [List of ambassadors of the United States to N...
#
# [540 rows x 20 columns]

# %%
df_connections.to_pickle('connections.pkl')
